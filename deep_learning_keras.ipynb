# %% [markdown]
# # Deep Learning avec Keras
#
# En guise d'initiation au Deep Learning, nous allons utiliser la bibliothèque Python [Keras](https://keras.io), basée sur [Tensorflow](https://www.tensorflow.org/).
#
# ## Objectifs
#
# Cette activité va nous permettre de :
#
# - Utiliser l'apprentissage profond pour des problèmes de vision par ordinateur
# - Utiliser des modèles pré-entrainés
# - Construire des modèles avec une approche par couche
# - Manipuler le bibliothèque Keras (et par extension Tensorflow)
#
# ## Installation
#
# **2 options** pour effectuer cette activité :
#
# - Utiliser votre machine locale : si vous n'avez pas un GPU NVidia, les phases d'entrainement seront très longues
# - Utiliser [Google Colab](https://colab.research.google.com/) avec option GPU : permet d'accélerer les phases d'entrainement
#
# D'ordre général, Keras étant désormais inclus avec Tensorflow, il suffit simplement d'installer la bibliothèque `tensorflow` :
#
# ```bash
# pip install tensorflow
# ```
#
# Si vous utilisez `pipenv`, un `Pipfile` avec les dépendances nécessaires est inclus dans ce dépôt. Si vous utilisez Colab, `tensorflow` est déjà installé.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from matplotlib_inline.backend_inline import set_matplotlib_formats
from tensorflow import keras

set_matplotlib_formats("svg")

# %% [markdown]
# ## Partie 1 : modèle pré-entrainé
#
# La liste des modèles pré-entrainés et inclus avec Keras est dans la section [Applications](https://keras.io/api/applications/).
# Les modèles pré-entrainés sont prêt à effectuer des prédictions : **vous n'avez pas besoin d'effectuer une phase d'entrainement !**
#
# Pour commencer en douceur, nous allons expérimenter avec un modèle pré-entrainé à classifier des images du jeu de données [ImageNet](https://en.wikipedia.org/wiki/ImageNet) : [ResNet50](https://keras.io/api/applications/resnet/#resnet50-function).
# Comme son nom l'indique, c'est un réseau de neurones convolutif (_CNN_) à 50 couches. Voici un schéma de son architecture :
#
# ![ResNet50 Schema](https://upload.wikimedia.org/wikipedia/commons/9/98/ResNet50.png)
#
# Objectif de cette partie :
#
# 1. Charger le modèle CNN ResNet50 avec Keras
# 2. Charger une photographie de votre choix au format `.jpg`, par exemple une voiture, une maison, un enfant, un instrument de musique, etc.
# 3. Effectuer le pré-traitement d'image requis par le modèle (bien lire la documentation du modèle ResNet50)
# 4. Effectuer la prédiction avec ResNet50
# 5. Tenter d'autres prédictions avec d'autres images

# %%
# YOUR CODE HERE
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt

# %%
model = ResNet50(weights='imagenet')

img_path = 'car1.png'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
plt.axis('off')
plt.show()

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 2023-02-05 04:39:11.792161: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 611ms/step
# Predicted: [('n03445924', 'golfcart', 0.6323935), ('n03594945', 'jeep', 0.26920664), ('n03769881', 'minibus', 0.06519817)]

# %%
img_path = 'guitar.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
plt.axis('off')
plt.show()

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 120ms/step
# Predicted: [('n03272010', 'electric_guitar', 0.9856141), ('n02676566', 'acoustic_guitar', 0.011093707), ('n02787622', 'banjo', 0.0013872074)]

# %% [markdown]
# ## Partie 2 : Perceptron multi-couche
#
# Nous allons commencer à construire notre premier réseau de neurones avec Keras. Nous allons utiliser la topologie de Perceptron multi-couche que vous connaissez déjà en utilisant un modèle [_Sequential_](https://keras.io/guides/sequential_model/), les couches [_Flatten_](https://keras.io/api/layers/reshaping_layers/flatten/) et [_Dense_](https://keras.io/api/layers/core_layers/dense/) de Keras.
#
# Voici l'architecture MLP que nous allons mettre en place (l'ordre des couches est à respecter) :
#
# - Une couche d'entrée d'applatissement (flattening) pour transformer une image 28 x 28 en un vecteur unidimensionnel de 784 features
# - Une couche cachée dense de 300 neurones avec fonction d'activation ReLU
# - Une couche cachée dense de 100 neurones avec fonction d'activation ReLU
# - Une couche de sortie dense de 10 neurones avec fonction d'activation SoftMax
#
# En utilisant le jeu de données [Fashion MNIST](https://keras.io/api/datasets/fashion_mnist/) inclus dans Keras :
#
# 1. Charger le jeu de données et normaliser les images 8-bit entre 0 et 1
# 2. Observer un exemplaire d'image de chaque classe
# 3. Construire le réseau de neurone MLP à 4 couches décrit ci-dessus
# 4. Afficher un résumé du modèle et observer les nombres de paramètres
# 5. Compiler le modèle
# 6. Entrainer le modèle sur 30 epochs avec 10% de cross-validation
# 7. Afficher les courbes d'apprentissage à partir de l'historique de la phase d'apprentissage pour vérifier le risque de sur-apprentissage
# 8. Evaluer le modèle sur le jeu de test
# 9. Effectuer quelques prédictions et vérifier les résultats en affichant les images

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.activations import softmax
from sklearn.model_selection import train_test_split

# %%
# Charger le jeu de données Fashion MNIST
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

print("X_train_full", X_train_full.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)

# Normaliser les images 8-bit entre 0 et 1
X_train = X_train_full / 255.0
X_test = X_test / 255.0

# Afficher un exemple d'image pour chaque classe
class_names = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]
# Out:
# X_train_full (60000, 28, 28)
# X_test (10000, 28, 28)
# y_test (10000,)

# %%
plt.figure(figsize=(12, 10))
for i in range(len(class_names)):
    idx = np.where(y_train_full == i)[0][0]
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(X_train[idx,:,:], cmap="binary")
    plt.title(class_names[i])
    plt.axis("off")

# Construire le réseau de neurone MLP à 4 couches
mlp_model = keras.models.Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(300, activation='relu'),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

# Afficher un résumé du modèle et observer les nombres de paramètres
mlp_model.summary()

# Compiler le modèle
mlp_model.compile(
    loss=keras.losses.sparse_categorical_crossentropy,
    optimizer=keras.optimizers.SGD(),
    metrics=[keras.metrics.sparse_categorical_accuracy],
)

# Entrainer le modèle sur 30 epochs avec 10% de cross-validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train_full, test_size=0.1)
history = mlp_model.fit(X_train, y_train, epochs=30, validation_data=(X_val, y_val))

# Afficher les courbes d'apprentissage à partir de l'historique de la phase d'apprentissage
pd.DataFrame(history.history).plot()
plt.grid(True)

# Evaluer le modèle sur le jeu de test
evaluation = mlp_model.evaluate(X_test, y_test)
print(evaluation)

# Effectuer quelques prédictions
y_pred_proba = mlp_model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)
print("y_pred_proba", y_pred_proba)
print("y_pred", y_pred)

# Vérifier les résultats en affichant les images
plt.figure(figsize=(5, 1))
for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(X_test[i,:,:], cmap="binary")
    plt.title(class_names[y_pred[i]])
    plt.axis("off")
# Out:
# X_train_full (60000, 28, 28)
# X_test (10000, 28, 28)
# y_test (10000,)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 300)               235500
#
#  dense_4 (Dense)             (None, 100)               30100
#
#  dense_5 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2023-02-05 05:17:55.249563: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1688/1688 [==============================] - ETA: 0s - loss: 0.7029 - sparse_categorical_accuracy: 0.7692
# 2023-02-05 05:18:05.253516: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1688/1688 [==============================] - 11s 5ms/step - loss: 0.7029 - sparse_categorical_accuracy: 0.7692 - val_loss: 0.5141 - val_sparse_categorical_accuracy: 0.8152
# Epoch 2/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4840 - sparse_categorical_accuracy: 0.8322 - val_loss: 0.4753 - val_sparse_categorical_accuracy: 0.8320
# Epoch 3/30
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.4410 - sparse_categorical_accuracy: 0.8463 - val_loss: 0.4245 - val_sparse_categorical_accuracy: 0.8493
# Epoch 4/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4139 - sparse_categorical_accuracy: 0.8543 - val_loss: 0.3855 - val_sparse_categorical_accuracy: 0.8642
# Epoch 5/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3950 - sparse_categorical_accuracy: 0.8622 - val_loss: 0.3887 - val_sparse_categorical_accuracy: 0.8635
# Epoch 6/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3795 - sparse_categorical_accuracy: 0.8667 - val_loss: 0.3873 - val_sparse_categorical_accuracy: 0.8617
# Epoch 7/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3666 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.3695 - val_sparse_categorical_accuracy: 0.8697
# Epoch 8/30
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.3543 - sparse_categorical_accuracy: 0.8746 - val_loss: 0.3519 - val_sparse_categorical_accuracy: 0.8738
# Epoch 9/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3439 - sparse_categorical_accuracy: 0.8780 - val_loss: 0.3484 - val_sparse_categorical_accuracy: 0.8748
# Epoch 10/30
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.3353 - sparse_categorical_accuracy: 0.8815 - val_loss: 0.3427 - val_sparse_categorical_accuracy: 0.8770
# Epoch 11/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3264 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.3785 - val_sparse_categorical_accuracy: 0.8597
# Epoch 12/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3182 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.3410 - val_sparse_categorical_accuracy: 0.8752
# Epoch 13/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3113 - sparse_categorical_accuracy: 0.8871 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.8737
# Epoch 14/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3048 - sparse_categorical_accuracy: 0.8912 - val_loss: 0.3267 - val_sparse_categorical_accuracy: 0.8802
# Epoch 15/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2985 - sparse_categorical_accuracy: 0.8929 - val_loss: 0.3461 - val_sparse_categorical_accuracy: 0.8720
# Epoch 16/30
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.2924 - sparse_categorical_accuracy: 0.8947 - val_loss: 0.3798 - val_sparse_categorical_accuracy: 0.8590
# Epoch 17/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2850 - sparse_categorical_accuracy: 0.8983 - val_loss: 0.3161 - val_sparse_categorical_accuracy: 0.8828
# Epoch 18/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2802 - sparse_categorical_accuracy: 0.8995 - val_loss: 0.3223 - val_sparse_categorical_accuracy: 0.8803
# Epoch 19/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2746 - sparse_categorical_accuracy: 0.9013 - val_loss: 0.3706 - val_sparse_categorical_accuracy: 0.8613
# Epoch 20/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2695 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.3164 - val_sparse_categorical_accuracy: 0.8838
# Epoch 21/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2646 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.3295 - val_sparse_categorical_accuracy: 0.8805
# Epoch 22/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2598 - sparse_categorical_accuracy: 0.9059 - val_loss: 0.3059 - val_sparse_categorical_accuracy: 0.8847
# Epoch 23/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2567 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.3262 - val_sparse_categorical_accuracy: 0.8785
# Epoch 24/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2511 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.3164 - val_sparse_categorical_accuracy: 0.8863
# Epoch 25/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2466 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.3203 - val_sparse_categorical_accuracy: 0.8840
# Epoch 26/30
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2427 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.3006 - val_sparse_categorical_accuracy: 0.8875
# Epoch 27/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2386 - sparse_categorical_accuracy: 0.9144 - val_loss: 0.3025 - val_sparse_categorical_accuracy: 0.8863
# Epoch 28/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2346 - sparse_categorical_accuracy: 0.9157 - val_loss: 0.3073 - val_sparse_categorical_accuracy: 0.8860
# Epoch 29/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2293 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.3056 - val_sparse_categorical_accuracy: 0.8890
# Epoch 30/30
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2277 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.2984 - val_sparse_categorical_accuracy: 0.8898
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3265 - sparse_categorical_accuracy: 0.8838
# [0.32649853825569153, 0.8838000297546387]
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ece42440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  91/313 [=======>......................] - ETA: 0s
# 2023-02-05 05:22:31.229375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# y_pred_proba [[8.36038510e-07 4.91492802e-09 1.13603323e-06 ... 6.31804112e-03
#   1.03117949e-04 9.90541279e-01]
#  [3.72792638e-05 1.90453857e-08 9.96365368e-01 ... 2.29813349e-10
#   4.04580305e-07 9.14961162e-10]
#  [1.87583773e-05 9.99979615e-01 8.10952088e-08 ... 2.39955611e-10
#   3.52815555e-08 1.00879710e-12]
#  ...
#  [5.40188607e-03 7.14197839e-08 1.29377900e-03 ... 1.12171756e-06
#   9.92617548e-01 1.42494031e-07]
#  [1.92799162e-05 9.99903440e-01 1.86673446e-06 ... 1.03195221e-08
#   1.50875181e-07 5.37003286e-09]
#  [1.34301590e-05 2.74882132e-06 7.93504078e-05 ... 4.95337602e-03
#   1.43095595e-03 1.16839146e-04]]
# y_pred [9 2 1 ... 8 1 5]

# %% [markdown]
# ## Partie 3 : Réseau de neurone convolutif
#
# Passons à l'étape supérieure désormais : construisons un réseau de neurones convolutif !
#
# En reprenant le modèle MLP précédent, nous allons l'adapter pour ajouter des couches convolutives avant les couches denses :
#
# - 1 première couche convolutive d'entrée de 64 filtres 7 x 7 (_Conv2D_) sur des données de dimensions 28 x 28 x 1
# - 1 couche de _max pooling_ de taille 2 (_MaxPooling2D_)
# - 2 couches convolutives successives de 128 filtres 3 x 3
# - 1 couche de _max pooling_ de taille 2
# - 2 couches convolutives successives de 256 filtres 3 x 3
# - 1 couche de _max pooling_ de taille 2
# - 1 couche d'applatissement pour revenir à un vecteur à 1 dimension
# - 1 couche dense de 128 neurones
# - 1 couche de perte de données (_Dropout_)
# - 1 couche dense de 64 neurones
# - 1 couche de perte de données
# - 1 couche dense de sortie de 10 neurones
#
# Le code vous correspond vous est fourni, vous devez simplement l'exécuter et observer les résultats. Normalement, ce modèle est censé atteindre 92% de justesse sur les données de test.

# %%
# Construction du modèle convolutif
cnn_model = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation=keras.activations.relu, padding="same", input_shape=[28, 28, 1]),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Conv2D(128, 3, activation=keras.activations.relu, padding="same"),
    keras.layers.Conv2D(128, 3, activation=keras.activations.relu, padding="same"),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Conv2D(256, 3, activation=keras.activations.relu, padding="same"),
    keras.layers.Conv2D(256, 3, activation=keras.activations.relu, padding="same"),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation=keras.activations.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation=keras.activations.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation=keras.activations.softmax),
])

# Afficher un résumé du modèle et observer les nombres de paramètres
cnn_model.summary()

# Compiler le modèle
cnn_model.compile(
    loss=keras.losses.sparse_categorical_crossentropy,
    optimizer=keras.optimizers.SGD(),
    metrics=[keras.metrics.sparse_categorical_accuracy],
)

# Entrainer le modèle
history = cnn_model.fit(X_train, y_train_full, epochs=30, validation_split=0.1)

# Afficher les courbes d'apprentissage à partir de l'historique de la phase d'apprentissage
pd.DataFrame(history.history).plot()
plt.grid(True)

# Evaluer le modèle sur le jeu de test
evaluation = cnn_model.evaluate(X_test, y_test)
print(evaluation)

# Effectuer quelques prédictions
y_pred_proba = cnn_model.predict(X_test[:3])
y_pred = np.argmax(y_pred_proba, axis=1)
print("y_pred_proba", y_pred_proba)
print("y_pred", y_pred)

# Vérifier les résultats en affichant les images
plt.figure(figsize=(5, 1))
for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(X_test[i,:,:], cmap="binary")
    plt.title(class_names[y_pred[i]])
    plt.axis("off")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 28, 28, 64)        3200
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 256)         295168
#
#  conv2d_9 (Conv2D)           (None, 7, 7, 256)         590080
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_9 (Dense)             (None, 128)               295040
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,413,834
# Trainable params: 1,413,834
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2023-02-05 05:51:52.963532: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1688/1688 [==============================] - ETA: 0s - loss: 1.2396 - sparse_categorical_accuracy: 0.5464
# 2023-02-05 05:52:31.525692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1688/1688 [==============================] - 41s 24ms/step - loss: 1.2396 - sparse_categorical_accuracy: 0.5464 - val_loss: 0.6896 - val_sparse_categorical_accuracy: 0.7400
# Epoch 2/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.6455 - sparse_categorical_accuracy: 0.7641 - val_loss: 0.5138 - val_sparse_categorical_accuracy: 0.8112
# Epoch 3/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.5214 - sparse_categorical_accuracy: 0.8102 - val_loss: 0.4833 - val_sparse_categorical_accuracy: 0.8195
# Epoch 4/30
# 1688/1688 [==============================] - 35s 21ms/step - loss: 0.4610 - sparse_categorical_accuracy: 0.8346 - val_loss: 0.4106 - val_sparse_categorical_accuracy: 0.8500
# Epoch 5/30
# 1688/1688 [==============================] - 35s 21ms/step - loss: 0.4140 - sparse_categorical_accuracy: 0.8514 - val_loss: 0.3843 - val_sparse_categorical_accuracy: 0.8607
# Epoch 6/30
# 1688/1688 [==============================] - 36s 22ms/step - loss: 0.3844 - sparse_categorical_accuracy: 0.8603 - val_loss: 0.3602 - val_sparse_categorical_accuracy: 0.8678
# Epoch 7/30
# 1688/1688 [==============================] - 38s 23ms/step - loss: 0.3580 - sparse_categorical_accuracy: 0.8710 - val_loss: 0.3463 - val_sparse_categorical_accuracy: 0.8745
# Epoch 8/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.3408 - sparse_categorical_accuracy: 0.8767 - val_loss: 0.3255 - val_sparse_categorical_accuracy: 0.8803
# Epoch 9/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.3237 - sparse_categorical_accuracy: 0.8820 - val_loss: 0.3284 - val_sparse_categorical_accuracy: 0.8723
# Epoch 10/30
# 1688/1688 [==============================] - 36s 22ms/step - loss: 0.3098 - sparse_categorical_accuracy: 0.8870 - val_loss: 0.3002 - val_sparse_categorical_accuracy: 0.8883
# Epoch 11/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.2953 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.3076 - val_sparse_categorical_accuracy: 0.8848
# Epoch 12/30
# 1688/1688 [==============================] - 36s 22ms/step - loss: 0.2835 - sparse_categorical_accuracy: 0.8970 - val_loss: 0.2952 - val_sparse_categorical_accuracy: 0.8895
# Epoch 13/30
# 1688/1688 [==============================] - 36s 21ms/step - loss: 0.2729 - sparse_categorical_accuracy: 0.9020 - val_loss: 0.2808 - val_sparse_categorical_accuracy: 0.8947
# Epoch 14/30
# 1688/1688 [==============================] - 36s 22ms/step - loss: 0.2631 - sparse_categorical_accuracy: 0.9042 - val_loss: 0.2788 - val_sparse_categorical_accuracy: 0.8973
# Epoch 15/30
# 1688/1688 [==============================] - 36s 22ms/step - loss: 0.2517 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.2673 - val_sparse_categorical_accuracy: 0.9007
# Epoch 16/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.2442 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.2761 - val_sparse_categorical_accuracy: 0.8973
# Epoch 17/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.2363 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.2891 - val_sparse_categorical_accuracy: 0.8898
# Epoch 18/30
# 1688/1688 [==============================] - 36s 22ms/step - loss: 0.2270 - sparse_categorical_accuracy: 0.9165 - val_loss: 0.2702 - val_sparse_categorical_accuracy: 0.8997
# Epoch 19/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.2176 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.2450 - val_sparse_categorical_accuracy: 0.9083
# Epoch 20/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.2086 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.2531 - val_sparse_categorical_accuracy: 0.9068
# Epoch 21/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.2032 - sparse_categorical_accuracy: 0.9265 - val_loss: 0.2490 - val_sparse_categorical_accuracy: 0.9093
# Epoch 22/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1946 - sparse_categorical_accuracy: 0.9289 - val_loss: 0.2800 - val_sparse_categorical_accuracy: 0.8937
# Epoch 23/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1882 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.2519 - val_sparse_categorical_accuracy: 0.9062
# Epoch 24/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1804 - sparse_categorical_accuracy: 0.9335 - val_loss: 0.2346 - val_sparse_categorical_accuracy: 0.9112
# Epoch 25/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1727 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.2397 - val_sparse_categorical_accuracy: 0.9115
# Epoch 26/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1661 - sparse_categorical_accuracy: 0.9390 - val_loss: 0.2478 - val_sparse_categorical_accuracy: 0.9063
# Epoch 27/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1604 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.2365 - val_sparse_categorical_accuracy: 0.9133
# Epoch 28/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1527 - sparse_categorical_accuracy: 0.9434 - val_loss: 0.2373 - val_sparse_categorical_accuracy: 0.9155
# Epoch 29/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1460 - sparse_categorical_accuracy: 0.9468 - val_loss: 0.2868 - val_sparse_categorical_accuracy: 0.9035
# Epoch 30/30
# 1688/1688 [==============================] - 37s 22ms/step - loss: 0.1400 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.2514 - val_sparse_categorical_accuracy: 0.9148
# 313/313 [==============================] - 3s 10ms/step - loss: 0.2650 - sparse_categorical_accuracy: 0.9080
# [0.26499825716018677, 0.9080000519752502]
# 1/1 [==============================] - 0s 140ms/step
# y_pred_proba [[2.2690384e-07 3.2554945e-07 1.1940924e-07 9.5780699e-08 8.1367357e-09
#   2.2057662e-05 1.1211533e-09 1.8503264e-04 9.9162015e-08 9.9979204e-01]
#  [5.1341325e-05 4.2593672e-07 9.9957937e-01 6.0786550e-07 6.2543462e-05
#   3.9961199e-07 3.0514700e-04 5.0013820e-09 5.3422095e-08 1.5801012e-07]
#  [4.4081543e-09 9.9999964e-01 9.5730457e-10 3.7924241e-07 4.8399751e-09
#   9.4063759e-12 4.0548906e-10 7.5871159e-10 9.9085899e-11 3.7949024e-10]]
# y_pred [9 2 1]
# 2023-02-05 06:10:18.855940: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
